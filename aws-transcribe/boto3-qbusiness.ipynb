# %%
import boto3


#Set boto3 default session to use the default profile
boto3.setup_default_session(profile_name='tsmlxl')

client = boto3.client('qbusiness')

# %%
id_q_anonymous='7b7b2282-43f0-47bf-aada-9857c3602b99'
id_q='66a11209-8e7c-43a0-92fa-f854aa546497'

# %%
response = client.get_web_experience(
    applicationId='66a11209-8e7c-43a0-92fa-f854aa546497',
    webExperienceId='8333e336-262b-4549-9b95-2f785da64012'
)

# %%
response = client.get_web_experience(
    applicationId='7b7b2282-43f0-47bf-aada-9857c3602b99',
    webExperienceId='d9640c93-d076-472b-8d9f-cf8a1dc16cd6'
)
# Out:
# ---------------------------------------------------------------------------
# ParamValidationError                      Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 response = client.get_web_experience(
#       2     #applicationId='7b7b2282-43f0-47bf-aada-9857c3602b99',
#       3     webExperienceId='d9640c93-d076-472b-8d9f-cf8a1dc16cd6'
#       4 )
#
# File d:\Work\Project\ts-sandbox-master\cookbook\aws-transcribe\venv\Lib\site-packages\botocore\client.py:595, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     591     raise TypeError(
#     592         f"{py_operation_name}() only accepts keyword arguments."
#     593     )
#     594 # The "self" in this scope is referring to the BaseClient.
# --> 595 return self._make_api_call(operation_name, kwargs)
#
# ...

# %%
response
# Out:
# {'ResponseMetadata': {'RequestId': 'd4e6ace8-5fe9-48fd-9eb8-baa972840970',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'd4e6ace8-5fe9-48fd-9eb8-baa972840970',
#    'strict-transport-security': 'max-age=47304000; includeSubDomains',
#    'cache-control': 'no-store, no-cache, no-cache',
#    'date': 'Mon, 30 Jun 2025 10:09:47 GMT',
#    'content-type': 'application/json',
#    'content-length': '1084',
#    'connection': 'close'},
#   'RetryAttempts': 0},
#  'applicationId': '66a11209-8e7c-43a0-92fa-f854aa546497',
#  'webExperienceId': '8333e336-262b-4549-9b95-2f785da64012',
#  'webExperienceArn': 'arn:aws:qbusiness:us-east-1:654654383273:application/66a11209-8e7c-43a0-92fa-f854aa546497/web-experience/8333e336-262b-4549-9b95-2f785da64012',
#  'defaultEndpoint': 'https://7ysshmqv.chat.qbusiness.us-east-1.on.aws/',
#  'status': 'ACTIVE',
#  'createdAt': datetime.datetime(2025, 6, 16, 10, 37, 29, 915000, tzinfo=tzlocal()),
# ...

# %%
response = client.list_applications(
    #nextToken='1',
    maxResults=100
)

response
# Out:
# {'ResponseMetadata': {'RequestId': '4ce099f4-31e2-4841-bac5-fe5f369d9ee4',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '4ce099f4-31e2-4841-bac5-fe5f369d9ee4',
#    'strict-transport-security': 'max-age=47304000; includeSubDomains',
#    'cache-control': 'no-store, no-cache, no-cache',
#    'date': 'Mon, 30 Jun 2025 10:01:15 GMT',
#    'content-type': 'application/json',
#    'content-length': '407',
#    'connection': 'close'},
#   'RetryAttempts': 0},
#  'applications': [{'displayName': 'demo-portalnet',
#    'applicationId': '66a11209-8e7c-43a0-92fa-f854aa546497',
#    'createdAt': datetime.datetime(2025, 6, 16, 10, 37, 18, 285000, tzinfo=tzlocal()),
#    'updatedAt': datetime.datetime(2025, 6, 16, 10, 37, 18, 285000, tzinfo=tzlocal()),
#    'status': 'ACTIVE',
#    'identityType': 'AWS_IAM_IDC'},
#   {'displayName': 'QBusiness-anonymous',
#    'applicationId': '89cc959c-c686-4996-aade-dcf91f392cb2',
# ...

# %%
response = client.list_web_experiences(
    #applicationId='89cc959c-c686-4996-aade-dcf91f392cb2',
    #applicationId='66a11209-8e7c-43a0-92fa-f854aa546497',
    applicationId=id_q_anonymous,
    #nextToken='string',
    maxResults=100
)
response
# Out:
# {'ResponseMetadata': {'RequestId': '17fb526e-79bd-4326-85aa-b17212d165bd',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '17fb526e-79bd-4326-85aa-b17212d165bd',
#    'strict-transport-security': 'max-age=47304000; includeSubDomains',
#    'cache-control': 'no-store, no-cache, no-cache',
#    'date': 'Mon, 30 Jun 2025 11:03:05 GMT',
#    'content-type': 'application/json',
#    'content-length': '223',
#    'connection': 'keep-alive'},
#   'RetryAttempts': 0},
#  'webExperiences': [{'webExperienceId': 'd9640c93-d076-472b-8d9f-cf8a1dc16cd6',
#    'createdAt': datetime.datetime(2025, 6, 30, 17, 55, 36, 220000, tzinfo=tzlocal()),
#    'updatedAt': datetime.datetime(2025, 6, 30, 17, 55, 36, 220000, tzinfo=tzlocal()),
#    'defaultEndpoint': 'https://jgva9aps.chat.qbusiness.us-east-1.on.aws/',
#    'status': 'ACTIVE'}]}

# %%
response = client.chat_sync(
    applicationId='66a11209-8e7c-43a0-92fa-f854aa546497',
    #userId='piramid@tradesquareltd.com',
     userGroups=[
        'arn:aws:iam::654654383273:role/aws-service-role/qbusiness.amazonaws.com/AWSServiceRoleForQBusiness',
     ],
    userMessage='Hi',
    # attachments=[
    #     {
    #         'data': b'bytes',
    #         'name': 'string',
    #         'copyFrom': {
    #             'conversation': {
    #                 'conversationId': 'string',
    #                 'attachmentId': 'string'
    #             }
    #         }
    #     },
    # ],
    # actionExecution={
    #     'pluginId': 'string',
    #     'payload': {
    #         'string': {
    #             'value': {...}|[...]|123|123.4|'string'|True|None
    #         }
    #     },
    #     'payloadFieldNameSeparator': 'string'
    # },
    # authChallengeResponse={
    #     'responseMap': {
    #         'string': 'string'
    #     }
    # },
    # conversationId='string',
    # parentMessageId='string',
    # attributeFilter={
    #     'andAllFilters': [
    #         {'... recursive ...'},
    #     ],
    #     'orAllFilters': [
    #         {'... recursive ...'},
    #     ],
    #     'notFilter': {'... recursive ...'},
    #     'equalsTo': {
    #         'name': 'string',
    #         'value': {
    #             'stringValue': 'string',
    #             'stringListValue': [
    #                 'string',
    #             ],
    #             'longValue': 123,
    #             'dateValue': datetime(2015, 1, 1)
    #         }
    #     },
    #     'containsAll': {
    #         'name': 'string',
    #         'value': {
    #             'stringValue': 'string',
    #             'stringListValue': [
    #                 'string',
    #             ],
    #             'longValue': 123,
    #             'dateValue': datetime(2015, 1, 1)
    #         }
    #     },
    #     'containsAny': {
    #         'name': 'string',
    #         'value': {
    #             'stringValue': 'string',
    #             'stringListValue': [
    #                 'string',
    #             ],
    #             'longValue': 123,
    #             'dateValue': datetime(2015, 1, 1)
    #         }
    #     },
    #     'greaterThan': {
    #         'name': 'string',
    #         'value': {
    #             'stringValue': 'string',
    #             'stringListValue': [
    #                 'string',
    #             ],
    #             'longValue': 123,
    #             'dateValue': datetime(2015, 1, 1)
    #         }
    #     },
    #     'greaterThanOrEquals': {
    #         'name': 'string',
    #         'value': {
    #             'stringValue': 'string',
    #             'stringListValue': [
    #                 'string',
    #             ],
    #             'longValue': 123,
    #             'dateValue': datetime(2015, 1, 1)
    #         }
    #     },
    #     'lessThan': {
    #         'name': 'string',
    #         'value': {
    #             'stringValue': 'string',
    #             'stringListValue': [
    #                 'string',
    #             ],
    #             'longValue': 123,
    #             'dateValue': datetime(2015, 1, 1)
    #         }
    #     },
    #     'lessThanOrEquals': {
    #         'name': 'string',
    #         'value': {
    #             'stringValue': 'string',
    #             'stringListValue': [
    #                 'string',
    #             ],
    #             'longValue': 123,
    #             'dateValue': datetime(2015, 1, 1)
    #         }
    #     }
    # },
    chatMode='CREATOR_MODE'
    # chatModeConfiguration={
    #     'pluginConfiguration': {
    #         'pluginId': 'string'
    #     }
    #},
    # clientToken='string'
)
# Out:
# ---------------------------------------------------------------------------
# AccessDeniedException                     Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 response = client.chat_sync(
#       2     applicationId='66a11209-8e7c-43a0-92fa-f854aa546497',
#       3     #userId='piramid@tradesquareltd.com',
#       4      userGroups=[
#       5         'arn:aws:iam::654654383273:role/aws-service-role/qbusiness.amazonaws.com/AWSServiceRoleForQBusiness',
#       6      ],
#       7     userMessage='Hi',
#       8     # attachments=[
#       9     #     {
#      10     #         'data': b'bytes',
#      11     #         'name': 'string',
#      12     #         'copyFrom': {
#      13     #             'conversation': {
#      14     #                 'conversationId': 'string',
#      15     #                 'attachmentId': 'string'
#      16     #             }
#      17     #         }
#      18     #     },
#      19     # ],
# ...

# %%
response = client.get_user(
    applicationId=id_q,
    userId='piramid@tradesquareltd.com'
)
response
# Out:
# {'ResponseMetadata': {'RequestId': 'd483f3ee-6a3a-44ae-935f-ce8fc081e191',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'd483f3ee-6a3a-44ae-935f-ce8fc081e191',
#    'strict-transport-security': 'max-age=47304000; includeSubDomains',
#    'cache-control': 'no-store, no-cache, no-cache',
#    'date': 'Mon, 30 Jun 2025 10:26:53 GMT',
#    'content-type': 'application/json',
#    'content-length': '98',
#    'connection': 'keep-alive'},
#   'RetryAttempts': 0},
#  'userAliases': [{'userId': 'piramid@tradesquareltd.com'}]}
